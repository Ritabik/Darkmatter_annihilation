# %% [markdown]
# # NFW_Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

def nfw_profile(r, rs, rhos):
    """
    NFW density profile function.

    Parameters:
        r (float or numpy array): Radius.
        rs (float): Scale radius.
        rho0 (float): Characteristic density.

    Returns:
        float or numpy array: NFW density profile at the given radius.
    """
    x = r / rs
    return rhos / (x * (1 + x)**2)

# Set the parameters for the NFW profile
r0 = 8.2
rs = 18.6 # Scale radius
rho0 =  0.383
rhos =  rho0*(r0/rs)*((1+(r0/rs))**2) # Characteristic density


r = np.linspace(10**(-9), 1, 100)

# Calculate the NFW density profile at each radius
density_NFW = nfw_profile(r, rs, rhos)
print(rhos)
# Plot the NFW profile
plt.plot(r, density_NFW, label='NFW Profile')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Radius(r in kpc)')
plt.ylabel('Density(rho in GeV/cm3)')
plt.title('NFW Profile')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 0.3505446810309352

# %% [markdown]
# # NFW+Spike GS benchmarks

# %%
import numpy as np
import matplotlib.pyplot as plt

def nfw_spikeGS(r,Rsp,gamma_sp):
    x = r / Rsp
    return  nfw_profile(Rsp, rs, rhos)*x**(-gamma_sp)

# Set the parameters for the NFW profile
r0 = 8.2
rs = 18.6 # Scale radius
rho0 =  0.383
Rsp = 0.34*10**(-3)
gamma_sp = 2.325
rhos =  rho0*(r0/rs)*((1+(r0/rs))**2) # Characteristic density


r = np.linspace(10**(-9), 1, 100)

# Calculate the NFW density profile at each radius
density_spikeGS = nfw_spikeGS(r,Rsp,gamma_sp)

# Plot the NFW profile
plt.plot(r, density_spikeGS, label='NFW spikeGS',color='r')
plt.plot(r, density_NFW, label='No spike',color='b')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Radius(r in kpc)')
plt.ylabel('Density(rho in GeV/cm3)')
plt.title('NFW Profile')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # NFW+Spike at Stellar heating benchmark

# %%
import numpy as np
import matplotlib.pyplot as plt

def nfw_Stellar(r, Rsp,gamma_sp):
    x = r / Rsp
    return  nfw_profile(Rsp, rs, rhos)*x**(-gamma_sp)

# Set the parameters for the NFW profile
r0 = 8.2
rs = 18.6 # Scale radius
rho0 =  0.383
Rsp = 0.34*10**(-3)
gamma_sp = 1.5
rhos =  rho0*(r0/rs)*((1+(r0/rs))**2) # Characteristic density


r = np.linspace(10**(-9), 1, 100)

# Calculate the NFW density profile at each radius
density_stellar = nfw_Stellar(r, Rsp,gamma_sp)

# Plot the NFW profile
plt.plot(r, density_stellar, label='Stellar Heating',color='r')
plt.plot(r, density_NFW, label='No spike',color='b')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Radius(r in kpc)')
plt.ylabel('Density(rho in GeV/cm3)')
plt.title('NFW Profile')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # NFW+Spike at BM benchmark

# %%
import numpy as np
import matplotlib.pyplot as plt

def nfw_BM(r, Rsp,gamma_sp):
    x = r / Rsp
    return  nfw_profile(Rsp, rs, rhos)*x**(-gamma_sp)

# Set the parameters for the NFW profile
r0 = 8.2
rs = 18.6 # Scale radius
rho0 =  0.383
gamma = 0.75
gamma_sp = 2.325
tau = 10
Rsp = (0.34*10**(-3))*(np.exp((-tau)/(2*(gamma_sp-gamma))))
rhos =  rho0*(r0/rs)*((1+(r0/rs))**2) # Characteristic density


r = np.linspace(10**(-9), 1, 100)

# Calculate the NFW density profile at each radius
density_BM = nfw_BM(r, Rsp,gamma_sp)

# Plot the NFW profile
plt.plot(r, density_BM, label='BM',color='r')
plt.plot(r, density_NFW, label='No spike',color='b')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Radius(r in kpc)')
plt.ylabel('Density(rho in GeV/cm3)')
plt.title('NFW Profile')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # NFW+Spike at less stellar heating benchmark

# %%
import numpy as np
import matplotlib.pyplot as plt

def nfw_lessstellar(r, Rsp, gamma_sp):
    x = np.where(r > 10**(-5), r, r / Rsp)
    return nfw_profile(x, rs, rhos) * x**(-gamma_sp)

# Set the parameters for the NFW profile
r0 = 8.2
rs = 18.6  # Scale radius
rho0 = 0.383
Rsp = 0.34 * 10**(-3)
gamma_sp = 2.325
rhos = rho0 * (r0 / rs) * ((1 + (r0 / rs))**2)


r = np.linspace(10**(-9), 1, 100)

# Calculate the NFW density profile at each radius
density_lesserheating = nfw_lessstellar(r, Rsp, gamma_sp)
print(rhos)
# Plot the NFW profile
plt.plot(r, density_lesserheating, label='Less Stellar', color='r')
plt.plot(r, density_NFW, label='No spike',color='b')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Radius (r in kpc)')
plt.ylabel('Density (rho in GeV/cm3)')
plt.title('NFW Profile')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 0.3505446810309352

# %% [markdown]
# # Combined plot

# %%
plt.plot(r, density_NFW, label='No spike',color='blue')
plt.plot(r, density_spikeGS, label='NFW spikeGS',color='red')
plt.plot(r, density_stellar, label='Stellar Heating',color='green')
plt.plot(r, density_BM, label='BM',color='orange')
plt.plot(r, density_lesserheating, label='Less Stellar', color='purple')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Radius (r in kpc)')
plt.ylabel('Density (rho in GeV/cm3)')
plt.title('NFW Profile')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Taking all the parameters from the paper and assuming no spike

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants and parameters
rs = 18.6  # Scale radius in kpc
rho0 = 0.383  # Local DM density in GeV/cm^3
r0 = 8.2  # Sun position in kpc
rho_sat = 3.17*10**11
gamma = 0.75
gamma_sp = 2.325
tau = 10
Rsp = (0.34*10**(-3))*(np.exp((-tau)/(2*(gamma_sp-gamma))))
# Function to calculate the NFW halo density profile
def nfw_halo(r, rs):
    x = r / rs
    return rhos / (x * (1 + x)**2)

# Function to calculate the DM mass density of the Milky Way
def mw_density_Nospike(r, Rs, Rsat, Rsp,gamma_sp):
    density = np.zeros_like(r)

    # Condition 1: r < 2RS
    mask_condition_1 = r < 2 * Rs
    density[mask_condition_1] = 0

    # Condition 2: 2RS ≤ r < Rsat
    mask_condition_2 = (r >= 2 * Rs) & (r < Rsat)
    density[mask_condition_2] = nfw_halo(r[mask_condition_2], rs)

    # Condition 3: Rsat ≤ r < Rsp
    mask_condition_3 = (r >= Rsat) & (r < Rsp)

    density[mask_condition_3] = nfw_halo(r[mask_condition_3], rs)

    # Condition 4: r ≥ Rsp
    mask_condition_4 = r >= Rsp
    density[mask_condition_4] = nfw_halo(r[mask_condition_4], rs)

    return density

# Generate radii from 0.01 to 100 times the scale radius
r = np.logspace(-9, 0, 100)
rhos = (rho0 * ((r0 / rs) * (1 + r0 / rs)**(2)))
# Parameters for the Milky Way density profile
Rs = 3.8*10**(-11)  # Example value for Rs# Example value for Rsat # Example value for Rsp
 # Example value for rhosat
Rsat = (((rhos/rho_sat)*(rs/Rsp)*((1+(Rsp/rs))**(-2)))**(1/gamma_sp))*Rsp

# Calculate the density profile for the Milky Way
density_mw_Nospike = mw_density_Nospike(r, Rs, Rsat, Rsp,gamma_sp)

# Plot the Milky Way density profile
plt.plot(r, density_mw_Nospike,label='BM', color='black')
plt.xlabel('Radius (r in kpc)')

plt.ylabel('Density (rho in GeV/cm^3)')
plt.title('Milky Way DM Density Profile')
plt.xscale('log')
plt.yscale('log')
plt.grid(True)
plt.legend()
plt.xlim([10**(-9), 1])  # Set the desired x-axis limits
plt.show()

# %% [markdown]
# # Taking all the parameters from the paper and assuming the GS becnchmark only

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants and parameters
rs = 18.6  # Scale radius in kpc
rho0 = 0.383  # Local DM density in GeV/cm^3
r0 = 8.2  # Sun position in kpc
rho_sat = 3.17*10**11

# Function to calculate the NFW halo density profile
def nfw_halo(r, rs):
    x = r / rs
    return rhos / (x * (1 + x)**2)

# Function to calculate the DM mass density of the Milky Way
def mw_density_GS(r, Rs, Rsat, Rsp,gamma_sp):
    density = np.zeros_like(r)

    # Condition 1: r < 2RS
    mask_condition_1 = r < 2 * Rs
    density[mask_condition_1] = 0

    # Condition 2: 2RS ≤ r < Rsat
    mask_condition_2 = (r >= 2 * Rs) & (r < Rsat)
    density[mask_condition_2] = rho_sat * (r[mask_condition_2] / Rsat)**(-0.5)

    # Condition 3: Rsat ≤ r < Rsp
    mask_condition_3 = (r >= Rsat) & (r < Rsp)
    x = r[mask_condition_3]/ Rsp
    density[mask_condition_3] = nfw_halo(Rsp, rs)*x**(-gamma_sp)

    # Condition 4: r ≥ Rsp
    mask_condition_4 = r >= Rsp
    density[mask_condition_4] = nfw_halo(r[mask_condition_4], rs)

    return density

# Generate radii from 0.01 to 100 times the scale radius
r = np.logspace(-9, 0, 100)
rhos = (rho0 * ((r0 / rs) * (1 + r0 / rs)**(2)))
# Parameters for the Milky Way density profile
Rs = 3.8*10**(-11)  # Example value for Rs# Example value for Rsat
Rsp = 0.34*10**(-3)  # Example value for Rsp
 # Example value for rhosat
gamma_sp=2.35
Rsat = (((rhos/rho_sat)*(rs/Rsp)*((1+(Rsp/rs))**(-2)))**(1/gamma_sp))*Rsp

# Calculate the density profile for the Milky Way
density_mw_GS = mw_density_GS(r, Rs, Rsat, Rsp,gamma_sp)

# Plot the Milky Way density profile
plt.plot(r, density_mw_GS,label='GS', color='b')
plt.xlabel('Radius (r in kpc)')

plt.ylabel('Density (rho in GeV/cm^3)')
plt.title('Milky Way DM Density Profile')
plt.xscale('log')
plt.yscale('log')
plt.grid(True)
plt.legend()
plt.xlim([10**(-9), 1])  # Set the desired x-axis limits
plt.show()

# %% [markdown]
# # Taking all the parameters from the paper and assuming the GS stellar heating only

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants and parameters
rs = 18.6  # Scale radius in kpc
rho0 = 0.383  # Local DM density in GeV/cm^3
r0 = 8.2  # Sun position in kpc
rho_sat = 3.17*10**11

# Function to calculate the NFW halo density profile
def nfw_halo(r, rs):
    x = r / rs
    return rhos / (x * (1 + x)**2)

# Function to calculate the DM mass density of the Milky Way
def mw_density_SH(r, Rs, Rsat, Rsp,gamma_sp):
    density = np.zeros_like(r)

    # Condition 1: r < 2RS
    mask_condition_1 = r < 2 * Rs
    density[mask_condition_1] = 0

    # Condition 2: 2RS ≤ r < Rsat
    mask_condition_2 = (r >= 2 * Rs) & (r < Rsat)
    density[mask_condition_2] = rho_sat * (r[mask_condition_2] / Rsat)**(-0.5)

    # Condition 3: Rsat ≤ r < Rsp
    mask_condition_3 = (r >= Rsat) & (r < Rsp)
    x = r[mask_condition_3]/ Rsp
    density[mask_condition_3] = nfw_halo(Rsp, rs)*x**(-gamma_sp)

    # Condition 4: r ≥ Rsp
    mask_condition_4 = r >= Rsp
    density[mask_condition_4] = nfw_halo(r[mask_condition_4], rs)

    return density

# Generate radii from 0.01 to 100 times the scale radius
r = np.logspace(-9, 0, 100)
rhos = (rho0 * ((r0 / rs) * (1 + r0 / rs)**(2)))
# Parameters for the Milky Way density profile
Rs = 3.8*10**(-11)  # Example value for Rs# Example value for Rsat
Rsp = 0.34*10**(-3)  # Example value for Rsp
 # Example value for rhosat
gamma_sp=1.5
Rsat = (((rhos/rho_sat)*(rs/Rsp)*((1+(Rsp/rs))**(-2)))**(1/gamma_sp))*Rsp

# Calculate the density profile for the Milky Way
density_mw_SH = mw_density_SH(r, Rs, Rsat, Rsp,gamma_sp)

# Plot the Milky Way density profile
plt.plot(r, density_mw_SH,label='stellar heating', color='r')
plt.xlabel('Radius (r in kpc)')

plt.ylabel('Density (rho in GeV/cm^3)')
plt.title('Milky Way DM Density Profile')
plt.xscale('log')
plt.yscale('log')
plt.grid(True)
plt.legend()
plt.xlim([10**(-9), 1])  # Set the desired x-axis limits
plt.show()

# %% [markdown]
# # Taking all the parameters from the paper and assuming the BM benchmark only

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants and parameters
rs = 18.6  # Scale radius in kpc
rho0 = 0.383  # Local DM density in GeV/cm^3
r0 = 8.2  # Sun position in kpc
rho_sat = 3.17*10**11
gamma = 0.75
gamma_sp = 2.325
tau = 10
Rsp = (0.34*10**(-3))*(np.exp((-tau)/(2*(gamma_sp-gamma))))
# Function to calculate the NFW halo density profile
def nfw_halo(r, rs):
    x = r / rs
    return rhos / (x * (1 + x)**2)

# Function to calculate the DM mass density of the Milky Way
def mw_density_BM(r, Rs, Rsat, Rsp,gamma_sp):
    density = np.zeros_like(r)

    # Condition 1: r < 2RS
    mask_condition_1 = r < 2 * Rs
    density[mask_condition_1] = 0

    # Condition 2: 2RS ≤ r < Rsat
    mask_condition_2 = (r >= 2 * Rs) & (r < Rsat)
    density[mask_condition_2] = rho_sat * (r[mask_condition_2] / Rsat)**(-0.5)

    # Condition 3: Rsat ≤ r < Rsp
    mask_condition_3 = (r >= Rsat) & (r < Rsp)
    x = r[mask_condition_3]/ Rsp
    density[mask_condition_3] = nfw_halo(Rsp, rs)*x**(-gamma_sp)

    # Condition 4: r ≥ Rsp
    mask_condition_4 = r >= Rsp
    density[mask_condition_4] = nfw_halo(r[mask_condition_4], rs)

    return density

# Generate radii from 0.01 to 100 times the scale radius
r = np.logspace(-9, 0, 100)
rhos = (rho0 * ((r0 / rs) * (1 + r0 / rs)**(2)))
# Parameters for the Milky Way density profile
Rs = 3.8*10**(-11)  # Example value for Rs# Example value for Rsat # Example value for Rsp
 # Example value for rhosat
Rsat = (((rhos/rho_sat)*(rs/Rsp)*((1+(Rsp/rs))**(-2)))**(1/gamma_sp))*Rsp

# Calculate the density profile for the Milky Way
density_mw_BM = mw_density_BM(r, Rs, Rsat, Rsp,gamma_sp)

# Plot the Milky Way density profile
plt.plot(r, density_mw_BM,label='BM', color='g')
plt.xlabel('Radius (r in kpc)')

plt.ylabel('Density (rho in GeV/cm^3)')
plt.title('Milky Way DM Density Profile')
plt.xscale('log')
plt.yscale('log')
plt.grid(True)
plt.legend()
plt.xlim([10**(-9), 1])  # Set the desired x-axis limits
plt.show()

# %% [markdown]
# # Combined Plot

# %%
plt.plot(r, density_mw_GS,label='GS', color='blue')
plt.plot(r, density_mw_BM,label='BM', color='green')
plt.plot(r, density_mw_SH,label='stellar heating', color='red')
plt.plot(r, density_mw_Nospike,label='BM', color='black')
plt.xlabel('Radius (r in kpc)')
plt.ylabel('Density (rho in GeV/cm^3)')
plt.title('Milky Way DM Density Profile')
plt.xscale('log')
plt.yscale('log')
plt.grid(True)
plt.legend()
plt.xlim([10**(-9), 1])  # Set the desired x-axis limits
plt.show()

# %% [markdown]
# # Changes by Manush (please feel free to edit it!)

# %% [markdown]
# ![Density parametrisation](../output/figures/Balaji2022_density_profiles.png)

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import sys,json,os
sys.path.append('../tools')
import profiles as tp
from profiles import Constants as pc
from profiles import MWDensity as pm

# %%
pm1 = pm(halo_types = ['NFW','Core'])
# Out:
# NFW, GS
# NFW, no spike
# NFW, NA
# NFW, SH
# NFW, SH-
# NFW, BM
# Core, GS
# Core, no spike
# Core, NA
# Core, SH
# Core, SH-
# Core, BM

# %%
import matplotlib
matplotlib.rcParams['text.usetex'] = False

# %%
fig,axs = plt.subplots(1,2,figsize = (12,4))
ax1,ax2 = axs

ax1.plot(pm1.r, pm1.density['NFW']['GS'], c = 'b', label = 'GS')
ax1.plot(pm1.r, pm1.density['NFW']['no spike'], c = 'k', label = 'no spike')
ax1.plot(pm1.r, pm1.density['NFW']['NA'], c = 'm', label = 'NA')
ax1.plot(pm1.r, pm1.density['NFW']['BM'], c = 'grey', label = 'BM')
ax1.plot(pm1.r, pm1.density['NFW']['SH-'], c = 'brown', label = r'$\bigstar$ heating$ -$')
ax1.plot(pm1.r, pm1.density['NFW']['SH'], c = 'cyan', label = r'$\bigstar$ heating')

ax2.plot(pm1.r, pm1.density['Core']['GS'], c = 'b', label = 'GS')
ax2.plot(pm1.r, pm1.density['Core']['no spike'], c = 'k', label = 'no spike')
ax2.plot(pm1.r, pm1.density['Core']['NA'], c = 'm', label = 'NA')
ax2.plot(pm1.r, pm1.density['Core']['BM'], c = 'grey', label = 'BM')
ax2.plot(pm1.r, pm1.density['Core']['SH-'], c = 'brown', label = r'$\bigstar$ heating$ -$')
ax2.plot(pm1.r, pm1.density['Core']['SH'], c = 'cyan', label = r'$\bigstar$ heating')

ax1.set_xscale('log')
ax1.set_yscale('log')
xticks = [10**i for i in range(-9,1)]
ax1.set_xticks(xticks)
ax1.set_xlim(8e-10,1.2e0)
yticks = [10**i for i in range(0,19,2)]
ax1.set_yticks(yticks)
ax1.set_ylim(1e0,5e18)
ax1.tick_params(which = 'both', direction = 'in', top = True, right = True)
ax1.legend(framealpha = 0)
ax1.grid()


ax2.set_xscale('log')
ax2.set_yscale('log')
xticks = [10**i for i in range(-9,1)]
ax2.set_xticks(xticks)
ax2.set_xlim(8e-10,1.2e0)
yticks = [10**i for i in range(0,19,2)]
ax2.set_yticks(yticks)
ax2.set_ylim(1e0,5e16)
ax2.tick_params(which = 'both', direction = 'in', top = True, right = True)
ax2.legend(framealpha = 0)
ax2.grid()
